# %% [markdown]
# improve network (using ch03-4)

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

from keras.datasets import imdb

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# Using TensorFlow backend.

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    # 크기가 (len(sequences), dimension))이고 모든 원소가 0인 행렬을 만듭니다
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.  # results[i]에서 특정 인덱스의 위치를 1로 만듭니다        
    return results

# 훈련 데이터를 벡터로 변환합니다
x_train = vectorize_sequences(train_data)
# 테스트 데이터를 벡터로 변환합니다
x_test = vectorize_sequences(test_data)

# vectorize label
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %% [markdown]
# original network (from ch03-4)

# %%
from keras import *

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )) )
model.add(layers.Dense(16, activation='relu') )
model.add(layers.Dense(1, activation=activations.sigmoid) )

# use function
model.compile(optimizer=optimizers.RMSprop(),
                loss=losses.binary_crossentropy,
#                 loss=losses.mse,
                metrics=[metrics.binary_accuracy]
               )

# learning
tb_hist = callbacks.TensorBoard(log_dir='./graph', histogram_freq=0, write_graph=True, write_images=True)

hist = model.fit(partial_x_train, partial_y_train, 
                    batch_size=512, 
                    epochs=20,
                    validation_data=(x_val, y_val),
                     callbacks=[tb_hist]                 
                  )

result = model.evaluate(x_test, y_test)
print(result)
# Out:
# WARNING:tensorflow:From /home/boom109/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/boom109/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 1s 70us/step - loss: 0.4811 - binary_accuracy: 0.7889 - val_loss: 0.3404 - val_binary_accuracy: 0.8807
# Epoch 2/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.2731 - binary_accuracy: 0.9029 - val_loss: 0.2860 - val_binary_accuracy: 0.8914
# Epoch 3/20
# 15000/15000 [==============================] - 1s 53us/step - loss: 0.1953 - binary_accuracy: 0.9330 - val_loss: 0.3314 - val_binary_accuracy: 0.8631
# Epoch 4/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.1575 - binary_accuracy: 0.9451 - val_loss: 0.2995 - val_binary_accuracy: 0.8814
# Epoch 5/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.1255 - binary_accuracy: 0.9575 - val_loss: 0.2974 - val_binary_accuracy: 0.8849
# Epoch 6/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0935 - binary_accuracy: 0.9704 - val_loss: 0.3337 - val_binary_accuracy: 0.8813
# Epoch 7/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0800 - binary_accuracy: 0.9744 - val_loss: 0.3393 - val_binary_accuracy: 0.8815
# Epoch 8/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0578 - binary_accuracy: 0.9835 - val_loss: 0.4226 - val_binary_accuracy: 0.8661
# Epoch 9/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0417 - binary_accuracy: 0.9896 - val_loss: 0.4345 - val_binary_accuracy: 0.8662
# Epoch 10/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0366 - binary_accuracy: 0.9903 - val_loss: 0.4749 - val_binary_accuracy: 0.8678
# Epoch 11/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0236 - binary_accuracy: 0.9951 - val_loss: 0.4718 - val_binary_accuracy: 0.8749
# Epoch 12/20
# 15000/15000 [==============================] - 1s 53us/step - loss: 0.0216 - binary_accuracy: 0.9948 - val_loss: 0.5046 - val_binary_accuracy: 0.8739
# Epoch 13/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0081 - binary_accuracy: 0.9995 - val_loss: 0.5441 - val_binary_accuracy: 0.8732
# Epoch 14/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0215 - binary_accuracy: 0.9947 - val_loss: 0.5726 - val_binary_accuracy: 0.8710
# Epoch 15/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0038 - binary_accuracy: 0.9999 - val_loss: 0.6029 - val_binary_accuracy: 0.8718
# Epoch 16/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0129 - binary_accuracy: 0.9960 - val_loss: 0.6296 - val_binary_accuracy: 0.8694
# Epoch 17/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0021 - binary_accuracy: 0.9999 - val_loss: 0.6594 - val_binary_accuracy: 0.8698
# Epoch 18/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0114 - binary_accuracy: 0.9965 - val_loss: 0.7171 - val_binary_accuracy: 0.8647
# Epoch 19/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 0.0012 - binary_accuracy: 0.9999 - val_loss: 0.7146 - val_binary_accuracy: 0.8682
# Epoch 20/20
# 15000/15000 [==============================] - 1s 52us/step - loss: 8.8088e-04 - binary_accuracy: 0.9999 - val_loss: 0.7503 - val_binary_accuracy: 0.8662
# 25000/25000 [==============================] - 1s 41us/step
# [0.8292644862890244, 0.8526]

# %% [markdown]
# ## network scaling

# %% [markdown]
# try make new network (as small network)

# %%
from keras import *

model = models.Sequential()
model.add(layers.Dense(6, activation='relu', input_shape=(10000, )) )
model.add(layers.Dense(6, activation='relu') )
model.add(layers.Dense(1, activation=activations.sigmoid) )

# use function
model.compile(optimizer=optimizers.RMSprop(),
                loss=losses.binary_crossentropy,
#                 loss=losses.mse,
                metrics=[metrics.binary_accuracy]
               )

# learning
tb_hist = callbacks.TensorBoard(log_dir='./graph', histogram_freq=0, write_graph=True, write_images=True,)

hist = model.fit(partial_x_train, partial_y_train, 
                    batch_size=512, 
                    epochs=20,
                    validation_data=(x_val, y_val),
                     callbacks=[tb_hist]                 
                  )

result = model.evaluate(x_test, y_test)
print(result)
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 1s 50us/step - loss: 0.6183 - binary_accuracy: 0.7365 - val_loss: 0.5501 - val_binary_accuracy: 0.8465
# Epoch 2/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.4752 - binary_accuracy: 0.8765 - val_loss: 0.4378 - val_binary_accuracy: 0.8642
# Epoch 3/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.3728 - binary_accuracy: 0.8986 - val_loss: 0.3675 - val_binary_accuracy: 0.8776
# Epoch 4/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.2989 - binary_accuracy: 0.9129 - val_loss: 0.3323 - val_binary_accuracy: 0.8731
# Epoch 5/20
# 15000/15000 [==============================] - 1s 43us/step - loss: 0.2483 - binary_accuracy: 0.9242 - val_loss: 0.2963 - val_binary_accuracy: 0.8885
# Epoch 6/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.2114 - binary_accuracy: 0.9364 - val_loss: 0.2817 - val_binary_accuracy: 0.8911
# Epoch 7/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.1829 - binary_accuracy: 0.9439 - val_loss: 0.2790 - val_binary_accuracy: 0.8887
# Epoch 8/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.1602 - binary_accuracy: 0.9498 - val_loss: 0.2727 - val_binary_accuracy: 0.8931
# Epoch 9/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.1403 - binary_accuracy: 0.9575 - val_loss: 0.2761 - val_binary_accuracy: 0.8920
# Epoch 10/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.1236 - binary_accuracy: 0.9629 - val_loss: 0.2900 - val_binary_accuracy: 0.8869
# Epoch 11/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.1098 - binary_accuracy: 0.9679 - val_loss: 0.2912 - val_binary_accuracy: 0.8871
# Epoch 12/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.0962 - binary_accuracy: 0.9735 - val_loss: 0.3082 - val_binary_accuracy: 0.8837
# Epoch 13/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.0856 - binary_accuracy: 0.9767 - val_loss: 0.3135 - val_binary_accuracy: 0.8839
# Epoch 14/20
# 15000/15000 [==============================] - 1s 43us/step - loss: 0.0756 - binary_accuracy: 0.9799 - val_loss: 0.3268 - val_binary_accuracy: 0.8829
# Epoch 15/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.0662 - binary_accuracy: 0.9831 - val_loss: 0.3471 - val_binary_accuracy: 0.8820
# Epoch 16/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.0579 - binary_accuracy: 0.9858 - val_loss: 0.3727 - val_binary_accuracy: 0.8767
# Epoch 17/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.0505 - binary_accuracy: 0.9891 - val_loss: 0.3796 - val_binary_accuracy: 0.8801
# Epoch 18/20
# 15000/15000 [==============================] - 1s 43us/step - loss: 0.0440 - binary_accuracy: 0.9907 - val_loss: 0.4045 - val_binary_accuracy: 0.8748
# Epoch 19/20
# 15000/15000 [==============================] - 1s 44us/step - loss: 0.0378 - binary_accuracy: 0.9919 - val_loss: 0.4235 - val_binary_accuracy: 0.8776
# Epoch 20/20
# 15000/15000 [==============================] - 1s 43us/step - loss: 0.0322 - binary_accuracy: 0.9937 - val_loss: 0.4428 - val_binary_accuracy: 0.8741
# 25000/25000 [==============================] - 1s 27us/step
# [0.4878179421186447, 0.86072]

# %% [markdown]
# try make new network (as big network)

# %%
from keras import *

model = models.Sequential()
model.add(layers.Dense(1024, activation='relu', input_shape=(10000, )) )
model.add(layers.Dense(1024, activation='relu') )
model.add(layers.Dense(1, activation=activations.sigmoid) )

# use function
model.compile(optimizer=optimizers.RMSprop(),
                loss=losses.binary_crossentropy,
#                 loss=losses.mse,
                metrics=[metrics.binary_accuracy]
               )

# learning
tb_hist = callbacks.TensorBoard(log_dir='./graph', histogram_freq=0, write_graph=True, write_images=True,)

hist = model.fit(partial_x_train, partial_y_train, 
                    batch_size=512, 
                    epochs=20,
                    validation_data=(x_val, y_val),
                     callbacks=[tb_hist]                 
                  )

result = model.evaluate(x_test, y_test)
print(result)
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 8s 503us/step - loss: 0.6827 - binary_accuracy: 0.7502 - val_loss: 0.3398 - val_binary_accuracy: 0.8631
# Epoch 2/20
# 15000/15000 [==============================] - 7s 497us/step - loss: 0.2621 - binary_accuracy: 0.8987 - val_loss: 0.2879 - val_binary_accuracy: 0.8916
# Epoch 3/20
# 15000/15000 [==============================] - 7s 497us/step - loss: 0.1162 - binary_accuracy: 0.9588 - val_loss: 0.3066 - val_binary_accuracy: 0.8914
# Epoch 4/20
# 15000/15000 [==============================] - 7s 497us/step - loss: 0.0865 - binary_accuracy: 0.9764 - val_loss: 0.3721 - val_binary_accuracy: 0.8902
# Epoch 5/20
# 15000/15000 [==============================] - 7s 496us/step - loss: 0.0033 - binary_accuracy: 0.9993 - val_loss: 0.5729 - val_binary_accuracy: 0.8756
# Epoch 6/20
# 15000/15000 [==============================] - 7s 497us/step - loss: 2.3359e-04 - binary_accuracy: 1.0000 - val_loss: 0.7559 - val_binary_accuracy: 0.8662
# Epoch 7/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 0.1975 - binary_accuracy: 0.9829 - val_loss: 0.5702 - val_binary_accuracy: 0.8883
# Epoch 8/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 6.2068e-05 - binary_accuracy: 1.0000 - val_loss: 0.6326 - val_binary_accuracy: 0.8873
# Epoch 9/20
# 15000/15000 [==============================] - 7s 497us/step - loss: 1.3246e-05 - binary_accuracy: 1.0000 - val_loss: 0.6849 - val_binary_accuracy: 0.8864
# Epoch 10/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 4.0808e-06 - binary_accuracy: 1.0000 - val_loss: 0.7159 - val_binary_accuracy: 0.8871
# Epoch 11/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 1.4097e-06 - binary_accuracy: 1.0000 - val_loss: 0.7580 - val_binary_accuracy: 0.8879
# Epoch 12/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 5.6407e-07 - binary_accuracy: 1.0000 - val_loss: 0.8020 - val_binary_accuracy: 0.8883
# Epoch 13/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 2.6419e-07 - binary_accuracy: 1.0000 - val_loss: 0.8438 - val_binary_accuracy: 0.8887
# Epoch 14/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 1.6528e-07 - binary_accuracy: 1.0000 - val_loss: 0.8792 - val_binary_accuracy: 0.8877
# Epoch 15/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 1.3177e-07 - binary_accuracy: 1.0000 - val_loss: 0.8953 - val_binary_accuracy: 0.8886
# Epoch 16/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 1.2014e-07 - binary_accuracy: 1.0000 - val_loss: 0.9074 - val_binary_accuracy: 0.8885
# Epoch 17/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 1.1549e-07 - binary_accuracy: 1.0000 - val_loss: 0.9158 - val_binary_accuracy: 0.8883
# Epoch 18/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 1.1348e-07 - binary_accuracy: 1.0000 - val_loss: 0.9245 - val_binary_accuracy: 0.8888
# Epoch 19/20
# 15000/15000 [==============================] - 7s 498us/step - loss: 1.1228e-07 - binary_accuracy: 1.0000 - val_loss: 0.9276 - val_binary_accuracy: 0.8884
# Epoch 20/20
# 15000/15000 [==============================] - 7s 497us/step - loss: 1.1168e-07 - binary_accuracy: 1.0000 - val_loss: 0.9335 - val_binary_accuracy: 0.8888
# 25000/25000 [==============================] - 6s 228us/step
# [1.0204811449962854, 0.87712]

# %% [markdown]
# ## 4.4.2 adding Regularization

# %% [raw]
# see below. Do use regularizer options to original Network.
#
# note.
# - from keras import regularizers
# - kernel_regularizer

# %%
from keras import *
from keras import regularizers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.001), input_shape=(10000, )) )
model.add(layers.Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.001)) )
model.add(layers.Dense(1, activation=activations.sigmoid) )

# use function
model.compile(optimizer=optimizers.RMSprop(),
                loss=losses.binary_crossentropy,
#                 loss=losses.mse,
                metrics=[metrics.binary_accuracy]
               )

# learning
tb_hist = callbacks.TensorBoard(log_dir='./graph', histogram_freq=0, write_graph=True, write_images=True)

hist = model.fit(partial_x_train, partial_y_train, 
                    batch_size=512, 
                    epochs=20,
                    validation_data=(x_val, y_val),
                     callbacks=[tb_hist]                 
                  )

result = model.evaluate(x_test, y_test)
print(result)
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.5777 - binary_accuracy: 0.7672 - val_loss: 0.4867 - val_binary_accuracy: 0.8149
# Epoch 2/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.3663 - binary_accuracy: 0.8923 - val_loss: 0.4248 - val_binary_accuracy: 0.8488
# Epoch 3/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.2956 - binary_accuracy: 0.9205 - val_loss: 0.3770 - val_binary_accuracy: 0.8737
# Epoch 4/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.2689 - binary_accuracy: 0.9285 - val_loss: 0.3642 - val_binary_accuracy: 0.8824
# Epoch 5/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.2488 - binary_accuracy: 0.9346 - val_loss: 0.3541 - val_binary_accuracy: 0.8837
# Epoch 6/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.2318 - binary_accuracy: 0.9419 - val_loss: 0.3531 - val_binary_accuracy: 0.8854
# Epoch 7/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.2239 - binary_accuracy: 0.9467 - val_loss: 0.3731 - val_binary_accuracy: 0.8820
# Epoch 8/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.2167 - binary_accuracy: 0.9501 - val_loss: 0.3709 - val_binary_accuracy: 0.8833
# Epoch 9/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.2025 - binary_accuracy: 0.9549 - val_loss: 0.3788 - val_binary_accuracy: 0.8807
# Epoch 10/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.1943 - binary_accuracy: 0.9589 - val_loss: 0.4164 - val_binary_accuracy: 0.8695
# Epoch 11/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.1966 - binary_accuracy: 0.9557 - val_loss: 0.4276 - val_binary_accuracy: 0.8682
# Epoch 12/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.1915 - binary_accuracy: 0.9581 - val_loss: 0.4162 - val_binary_accuracy: 0.8755
# Epoch 13/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.1886 - binary_accuracy: 0.9595 - val_loss: 0.4471 - val_binary_accuracy: 0.8657
# Epoch 14/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.1718 - binary_accuracy: 0.9689 - val_loss: 0.4171 - val_binary_accuracy: 0.8777
# Epoch 15/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.1745 - binary_accuracy: 0.9681 - val_loss: 0.5215 - val_binary_accuracy: 0.8515
# Epoch 16/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.1791 - binary_accuracy: 0.9639 - val_loss: 0.4379 - val_binary_accuracy: 0.8734
# Epoch 17/20
# 15000/15000 [==============================] - 1s 72us/step - loss: 0.1664 - binary_accuracy: 0.9703 - val_loss: 0.6279 - val_binary_accuracy: 0.8308
# Epoch 18/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.1718 - binary_accuracy: 0.9679 - val_loss: 0.4502 - val_binary_accuracy: 0.8730
# Epoch 19/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.1614 - binary_accuracy: 0.9719 - val_loss: 0.5580 - val_binary_accuracy: 0.8470
# Epoch 20/20
# 15000/15000 [==============================] - 1s 73us/step - loss: 0.1604 - binary_accuracy: 0.9717 - val_loss: 0.5152 - val_binary_accuracy: 0.8577
# 25000/25000 [==============================] - 1s 45us/step
# [0.5455117295837403, 0.848]

# %% [markdown]
# ## 4.4.3 dropout

# %%
from keras import *

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000, )) )
model.add(layers.Dropout(0.5))
model.add(layers.Dense(16, activation='relu') )
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation=activations.sigmoid) )

# use function
model.compile(optimizer=optimizers.RMSprop(),
                loss=losses.binary_crossentropy,
#                 loss=losses.mse,
                metrics=[metrics.binary_accuracy]
               )

# learning
tb_hist = callbacks.TensorBoard(log_dir='./graph', histogram_freq=0, write_graph=True, write_images=True)

hist = model.fit(partial_x_train, partial_y_train, 
                    batch_size=512, 
                    epochs=20,
                    validation_data=(x_val, y_val),
                     callbacks=[tb_hist]                 
                  )

result = model.evaluate(x_test, y_test)
print(result)
# Out:
# WARNING:tensorflow:From /home/boom109/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# 15000/15000 [==============================] - 1s 76us/step - loss: 0.6322 - binary_accuracy: 0.6286 - val_loss: 0.5393 - val_binary_accuracy: 0.8421
# Epoch 2/20
# 15000/15000 [==============================] - 1s 64us/step - loss: 0.5108 - binary_accuracy: 0.7688 - val_loss: 0.4184 - val_binary_accuracy: 0.8708
# Epoch 3/20
# 15000/15000 [==============================] - 1s 64us/step - loss: 0.4294 - binary_accuracy: 0.8243 - val_loss: 0.3524 - val_binary_accuracy: 0.8796
# Epoch 4/20
# 15000/15000 [==============================] - 1s 64us/step - loss: 0.3673 - binary_accuracy: 0.8559 - val_loss: 0.3119 - val_binary_accuracy: 0.8865
# Epoch 5/20
# 15000/15000 [==============================] - 1s 64us/step - loss: 0.3199 - binary_accuracy: 0.8809 - val_loss: 0.2860 - val_binary_accuracy: 0.8910
# Epoch 6/20
# 15000/15000 [==============================] - 1s 64us/step - loss: 0.2800 - binary_accuracy: 0.8999 - val_loss: 0.2730 - val_binary_accuracy: 0.8917
# Epoch 7/20
# 15000/15000 [==============================] - 1s 65us/step - loss: 0.2420 - binary_accuracy: 0.9117 - val_loss: 0.2762 - val_binary_accuracy: 0.8909
# Epoch 8/20
# 15000/15000 [==============================] - 1s 65us/step - loss: 0.2203 - binary_accuracy: 0.9229 - val_loss: 0.2795 - val_binary_accuracy: 0.8933
# Epoch 9/20
# 15000/15000 [==============================] - 1s 65us/step - loss: 0.1970 - binary_accuracy: 0.9321 - val_loss: 0.2969 - val_binary_accuracy: 0.8876
# Epoch 10/20
# 15000/15000 [==============================] - 1s 65us/step - loss: 0.1772 - binary_accuracy: 0.9397 - val_loss: 0.3054 - val_binary_accuracy: 0.8896
# Epoch 11/20
# 15000/15000 [==============================] - 1s 64us/step - loss: 0.1606 - binary_accuracy: 0.9442 - val_loss: 0.3188 - val_binary_accuracy: 0.8867
# Epoch 12/20
# 15000/15000 [==============================] - 1s 65us/step - loss: 0.1454 - binary_accuracy: 0.9513 - val_loss: 0.3475 - val_binary_accuracy: 0.8881
# Epoch 13/20
# 15000/15000 [==============================] - 1s 67us/step - loss: 0.1263 - binary_accuracy: 0.9601 - val_loss: 0.3866 - val_binary_accuracy: 0.8819
# Epoch 14/20
# 15000/15000 [==============================] - 1s 70us/step - loss: 0.1243 - binary_accuracy: 0.9568 - val_loss: 0.3932 - val_binary_accuracy: 0.8876
# Epoch 15/20
# 15000/15000 [==============================] - 1s 68us/step - loss: 0.1147 - binary_accuracy: 0.9628 - val_loss: 0.4220 - val_binary_accuracy: 0.8791
# Epoch 16/20
# 15000/15000 [==============================] - 1s 68us/step - loss: 0.1059 - binary_accuracy: 0.9655 - val_loss: 0.4103 - val_binary_accuracy: 0.8875
# Epoch 17/20
# 15000/15000 [==============================] - 1s 67us/step - loss: 0.0964 - binary_accuracy: 0.9688 - val_loss: 0.4574 - val_binary_accuracy: 0.8850
# Epoch 18/20
# 15000/15000 [==============================] - 1s 66us/step - loss: 0.0921 - binary_accuracy: 0.9683 - val_loss: 0.4939 - val_binary_accuracy: 0.8813
# Epoch 19/20
# 15000/15000 [==============================] - 1s 66us/step - loss: 0.0895 - binary_accuracy: 0.9700 - val_loss: 0.5007 - val_binary_accuracy: 0.8834
# Epoch 20/20
# 15000/15000 [==============================] - 1s 66us/step - loss: 0.0808 - binary_accuracy: 0.9734 - val_loss: 0.5484 - val_binary_accuracy: 0.8815
# 25000/25000 [==============================] - 1s 33us/step
# [0.5947406792998314, 0.87032]
